# %% [markdown]
# # Introducción
#
# En la sesión de hoy comenzaremos a trabajar con Pandas, la librería más utilizada en el mundo Python para el análisis de datos y el manejo de DataFrames.

# %% [markdown]
# # Primer paso
#
# El primer y más importante paso es importar la librería Pandas para poder utilizarla en nuestro código.

# %%
import pandas as pd

# %% [markdown]
# # Dataframes
#
# Los dataframes es el tipo de estructura de datos más importante en Pandas. Podemos pensar en ellos como una tabla o matriz, que estará formada por tanto por N filas y M columnas.
#
# La función DataFrame nos permite crear DataFrames. Solo necesitamos introducir los datos.

# %%
#Introducimos los datos de cada fila
mi_tabla =  pd.DataFrame( [[50, "María"], [31, "Juan"], [18, "Silvia"]])
mi_tabla
# Out:
#     0       1
# 0  50   María
# 1  31    Juan
# 2  18  Silvia

# %%
#Podemos darle nombre a las columnas con el parametro "columns"
pd.DataFrame( [[50, "María"], [31, "Juan"], [18, "Silvia"]], columns=["Edad", "Nombre"])
# Out:
#    Edad  Nombre
# 0    50   María
# 1    31    Juan
# 2    18  Silvia

# %%
#Es más típico crearlo con un diccionario, ya que nos permite directamente indicar también el nombre de las columnas.
mi_tabla = pd.DataFrame( {"Edad":[50,31,18], "Nombre": ["María", "Juan", "Silvia"]}  )
mi_tabla
# Out:
#    Edad  Nombre
# 0    50   María
# 1    31    Juan
# 2    18  Silvia

# %%
mi_tabla.Edad
# Out:
# 0    50
# 1    31
# 2    18
# Name: Edad, dtype: int64

# %%
mi_tabla.Nombre
# Out:
# 0     María
# 1      Juan
# 2    Silvia
# Name: Nombre, dtype: object

# %%
mi_tabla.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
Id = [1,2,3]
mi_tabla.index = Id
mi_tabla
# Out:
#    Edad  Nombre
# 1    50   María
# 2    31    Juan
# 3    18  Silvia

# %% [markdown]
# #Series
#
# Por otro lado, tenemos otra estructura de datos impotante en Pandas que, aunque sea menos utilizada que los dataframes, tiene sus utilidades.
# Esta estructura son las series, que son estructuras unidimensionales conteniendo un array de datos y un array de etiquetas que van asociadas a los datos, llamado índice (index ):

# %%
ventas = pd.Series ([10, 20, 16], index = ['Enero', 'Febrero', 'Marzo'])
ventas
# Out:
# Enero      10
# Febrero    20
# Marzo      16
# dtype: int64

# %%
ventas.index
# Out:
# Index(['Enero', 'Febrero', 'Marzo'], dtype='object')

# %%
ventas[0]
# Out:
# 10

# %%
ventas['Enero']
# Out:
# 10

# %% [markdown]
# #EJERCICIO 1
#
# Crea, a partir de un diccionario, un DataFrame llamado data con los datos de la tabla siguiente:
#
#
# |Mes|Ventas|Gastos|
# | - | - | - |
# |Enero| 30500|22000|
# |Febrero|34120|23400|
# |Marzo|31200|25112|
# |Abril|36500|21300|
#
# *Nota: La columna Mes ha de ser el index

# %%
data = 
data = data.set_index('Mes') #función que fija como índice una de las columnas del dataframe creado
data
# Out:
#   File "<ipython-input-14-8cb14e040ed2>", line 1
#     data =
#            ^
# SyntaxError: invalid syntax

# %%
data = pd.DataFrame({'Ventas': [30500, 34120, 31200, 36500], 'Gastos': [22000,23400,25112,21300], 'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril']})
data = data.set_index('Mes')
data
# Out:
#          Ventas  Gastos
# Mes
# Enero     30500   22000
# Febrero   34120   23400
# Marzo     31200   25112
# Abril     36500   21300

# %%
data.Ventas
# Out:
# Mes
# Enero      30500
# Febrero    34120
# Marzo      31200
# Abril      36500
# Name: Ventas, dtype: int64

# %%
data.index
# Out:
# Index(['Enero', 'Febrero', 'Marzo', 'Abril'], dtype='object', name='Mes')

# %% [markdown]
# # Entendiendo el Index
#
# Los DataFrames de Pandas tienen un campo llamado Index, que facilita el acceder a los datos de una manera más fácil. También permite dar un nombre a cada fila, lo que facilita el trabajar con el DataFrame.
#
#
# Veréis que al no hacerlo en los ejemplos anteriores, se creó un Index 0,1,2... para cada fila del dataframe automáticamente, mientras que en el ejemplo siguiente cada fila toma la etiqueta o nombre que nosotros le indicamos.

# %%
pd.DataFrame( {"Edad":[50,31,18], "Nombre": ["María", "Juan", "Silvia"]}, index=["Cliente1", "Cliente2", "Cliente3"])
# Out:
#           Edad  Nombre
# Cliente1    50   María
# Cliente2    31    Juan
# Cliente3    18  Silvia

# %% [markdown]
# ## Puedes tratar de repetir el ejercicio 1 creando el dataframe de Ventas y Gastos por mes de esta forma.

# %%
data = pd.DataFrame({'Ventas': [30500, 34120, 31200, 36500], 'Gastos': [22000,23400,25112,21300]}, index = ['Enero', 'Febrero', 'Marzo', 'Abril'])
data
# Out:
#          Ventas  Gastos
# Enero     30500   22000
# Febrero   34120   23400
# Marzo     31200   25112
# Abril     36500   21300

# %% [markdown]
# #Leyendo datos de un fichero
#
# Lo más habitual es tener los datos en un fichero en el ordenador o un sistema externo. Para leer datos y guardarlos en un DataFrame, la forma más fácil es utilizar la función read_csv de pandas, lo que nos permite leer un fichero CSV, ya esté en local.
#
# Para ello solo tenemos que indicarle donde está el fichero. En este caso, lo leeremos de una ruta pública de GitHub.

# %%
url_fichero = "https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/house_prices.csv"
house_prices = pd.read_csv(url_fichero)


#La función head() nos permite mostrar las primeras lineas del archivo
house_prices.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
house_prices.set_index('Id')
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                      ...
# 1             60       RL         65.0  ...        WD        Normal    208500
# 2             20       RL         80.0  ...        WD        Normal    181500
# 3             60       RL         68.0  ...        WD        Normal    223500
# 4             70       RL         60.0  ...        WD       Abnorml    140000
# 5             60       RL         84.0  ...        WD        Normal    250000
# ...          ...      ...          ...  ...       ...           ...       ...
# 1456          60       RL         62.0  ...        WD        Normal    175000
# 1457          20       RL         85.0  ...        WD        Normal    210000
# 1458          70       RL         66.0  ...        WD        Normal    266500
# 1459          20       RL         68.0  ...        WD        Normal    142125
# ...

# %% [markdown]
# La función **read_csv** tiene muchos más argumentos que nos permiten hacer múltiples acciones a la hora de leer el archivo.
#
# Por ejemplo podemos indicar el separador de cada línea del fichero con "sep", pero hay muchos otras opciones que podemos consultar en la[ documentación oficial.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
#Si tuvieramos un fichero en nuestro ordenador, y quisiéramos leerlo con pandas, tendríamos que pasarle la ruta del archivo.
#Por ejemplo, si lo tenemos en la carpeta de descargas de nuestro equipo, tendríamos que hacer algo así:
data = pd.read_csv('C:/Usuarios/Toni/Descargas/california_housing_kaggle')
data.head()

#Esto funcionaría con la mayoría de enviroments porque trabajan en local. Sin embargo, Google Colab trabaja 
#en la red por lo que debemos primero subir el fichero como veréis en la siguiente celda de código
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-7707712e578f> in <module>()
#       1 #Si tuvieramos un fichero en nuestro ordenador, y quisiéramos leerlo con pandas, tendríamos que pasarle la ruta del archivo.
#       2 #Por ejemplo, si lo tenemos en la carpeta de descargas de nuestro equipo, tendríamos que hacer algo así:
# ----> 3 data = pd.read_csv('C:/Usuarios/Toni/Descargas/california_housing_kaggle')
#       4 data.head()
#       5
#
# ...

# %%
#No es necesario que os aprendáis este código pero aquí lo tenéis por si en el futuro trabjáis con colab y quéreis manipular datos de ficheros que tenéis en local (en vuestro equipo)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2cf84d2-9044-40a8-a270-f10d277129f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2cf84d2-9044-40a8-a270-f10d277129f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-90f5f0850281> in <module>()
#       1 #No es necesario que os aprendáis este código pero aquí lo tenéis por si en el futuro trabjáis con colab y quéreis manipular datos de ficheros que tenéis en local (en vuestro equipo)
#       2 from google.colab import files
# ----> 3 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
# ...

# %%
import io
california_housing_kaggle = pd.read_csv(io.BytesIO(uploaded['california_housing_kaggle.csv']))
california_housing_kaggle

# %% [markdown]
# #Leyendo datos de una base de datos
# Python, y concretamente Pandas nos permite conectarnos a una base de datos y ejecutar código SQL para recuperar datos y guardarlos en un DataFrame.
#
# Para este ejemplo, utilizaremos la libreria sqlite que creará una pequeña base de datos a la que nos podremos

# %%
####################  ESTE TROZO DE CÓDIGO NOS CREARÁ UNA PEQUEÑA BASE DE DATOS PARA UTILIZAR DE EJEMPLO. ####
####################   NO ES NECESARIO QUE LO APRENDÁIS, SOLO EJECUTARLO UNA VEZ                          ####
# Importamos SQLite
import sqlite3 
# conectamos a la BD
db_con = sqlite3.connect(r'database.db') 
# Leemos todos los csvs
c = pd.read_excel('https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/movies.xlsx')
o = pd.read_excel("https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/gender.xlsx")
r = pd.read_excel("https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/actors.xlsx")
p = pd.read_excel("https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/actor_movies.xlsx")
# Escribimos los txts como tablas en la base de datos.
c.to_sql('movies', db_con, if_exists='replace', index=False) 
o.to_sql('gender', db_con, if_exists='replace', index=False) 
r.to_sql('actors', db_con, if_exists='replace', index=False) 
p.to_sql('actor_movies', db_con, if_exists='replace', index=False) 

#Cerramos la conexion.
db_con.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#Para conectarse a una base de datos necesitamos primero saber donde se encuentra, y normalmente usuario y contraseña. 
#Pero en esta ocasion nos basta con ejecutar la siguiente línea.
db_con = sqlite3.connect(r'database.db')

# %%
#Con la función read_sql de pandas podemos introducir código SQL y extraer datos de una base de datos.
#Solo necesitamos introducir dos argumentos: la consulta SQL, y la conexión a la base de datos.
actors = pd.read_sql("SELECT * FROM actors", db_con)
actors
# Out:
#     act_id           act_fname   act_lname act_gender
# 0               101      James     Stewart          M
# 1               102    Deborah        Kerr          F
# 2               103      Peter      Otoole          M
# 3               104     Robert     De Niro          M
# 4               105   F.Murray     Abraham          M
# 5               106   Harrison        Ford          M
# 6               107     Nicole      Kidman          F
# 7               108    Stephen     Bladwin          M
# 8               109       Jack   Nicholson          M
# 9               110       Mark    Wahlberg          M
# 10              111      Woody       Allen          M
# 11              112     Claire       Danes          F
# 12              113        Tim     Robbins          M
# 13              114      Kevin      Spacey          M
# 14              115       Kate     Winslet          F
# 15              116      Robin    Williams          M
# ...

# %%
type(actors)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Recordad que podemos mezclar tablas con JOIN, para aprovechar y traernos ya los datos mezclados en un mismo dataframe.

# %%
movies_and_genders = pd.read_sql("SELECT * FROM movies JOIN gender ON movies.genero = gender.genero", db_con)
movies_and_genders.head()
# Out:
#    mov_id           mov_title  mov_year  ... genero genero  gen_title
# 0     901             Vertigo      1958  ...   1010   1010    Mystery
# 1     902       The Innocents      1961  ...   1008   1008     Horror
# 2     903  Lawrence of Arabia      1962  ...   1002   1002  Adventure
# 3     904     The Deer Hunter      1978  ...   1013   1013        War
# 4     905             Amadeus      1984  ...   1004   1004  Biography
#
# [5 rows x 10 columns]

# %% [markdown]
# Ya sabemos conseguir datos de 3 maneras diferentes:
#
#
# 1.   Creando un dataframe nosotros mismos (con diccionarios o listas)
# 2.   Leyendo de ficheros CSV
# 3.   Conectandonos a una base de datos y ejecutando código SQL para traernos el resultado.

# %% [markdown]
# # EJERCICIO 2

# %% [markdown]
# CON SQL:
# 1. Selecciona los tres primeros registros de la tabla movies. SELECT, FROM, LIMIT
# 2. Selecciona las columnas id, title y time solamente de los 5 primeros registros de la tabla movies. SELECT, FROM, LIMIT
# 3. Muestra los países de origen de las distintas películas de la tabla movies (sin repetir). SELECT, DISTINCT, FROM
# 5. Selecciona las tres primeras películas donde el año sea mayor a 1990 y la duración mayor a 100 minutos. SELECT, WHERE, FROM, LIMIT
# 6. Por país, cuenta el número de películas y obtén la duración promedio de las películas. SELECT, COUNT(), AVG(), FROM, ORDER BY
# 7. Obtén los nombres de las películas de género Drama. SELECT, FROM, JOIN, WHERE

# %%
#Selecciona los tres primeros registros de la tabla movies. SELECT, FROM, LIMIT
ex2_1 = pd.read_sql("SELECT * FROM movies LIMIT 3", db_con)
ex2_1
# Out:
#    mov_id           mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 0     901             Vertigo      1958  ...  1958-08-24              UK   1010
# 1     902       The Innocents      1961  ...  1962-02-19              SW   1008
# 2     903  Lawrence of Arabia      1962  ...  1962-12-11              UK   1002
#
# [3 rows x 8 columns]

# %%
#Selecciona las columnas id, title y time solamente de los 5 primeros registros de la tabla movies. SELECT, FROM, LIMIT
ex2_2 = pd.read_sql("SELECT mov_id, mov_title, mov_time FROM movies LIMIT 5", db_con)
ex2_2
# Out:
#    mov_id           mov_title  mov_time
# 0     901             Vertigo       128
# 1     902       The Innocents       100
# 2     903  Lawrence of Arabia       216
# 3     904     The Deer Hunter       183
# 4     905             Amadeus       160

# %%
movies.columns
# Out:
# Index(['mov_id', 'mov_title', 'mov_year', 'mov_time', 'mov_lang', 'mov_dt_rel',
#        'mov_rel_country', 'genero', 'mov_time_in_secs'],
#       dtype='object')

# %%
#Muestra los países de origen de las distintas películas de la tabla movies (sin repetir). SELECT, DISTINCT, FROM
ex2_3 = pd.read_sql("SELECT DISTINCT mov_rel_country FROM movies", db_con)
ex2_3
# Out:
#   mov_rel_country
# 0              UK
# 1              SW
# 2            None
# 3             USA
# 4              JP

# %%
#Selecciona las tres primeras películas donde el año sea mayor a 1990 y la duración mayor a 100 minutos. SELECT, WHERE, FROM, LIMIT
ex2_4 =  pd.read_sql("SELECT * FROM movies WHERE mov_year > 1990 and mov_time > 100 LIMIT 3", db_con)
ex2_4
# Out:
#    mov_id           mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 0     907     Eyes Wides Shut      1999  ...          UK            None   1010
# 1     908  The Usual Suspects      1995  ...  1995-08-25              UK   1006
# 2     910       Boogie Nights      1997  ...  1998-02-16              UK   1005
#
# [3 rows x 8 columns]

# %%
#Por país, cuenta el número de películas y obtén la duración promedio de las películas. SELECT, COUNT(), AVG(), GROUP BY, FROM
ex2_5 =  pd.read_sql("SELECT mov_rel_country, COUNT(mov_id) AS number_of_movies, AVG (mov_time) AS avg_time FROM movies GROUP BY mov_rel_country", db_con)
ex2_5
# Out:
#   mov_rel_country  number_of_movies  avg_time
# 0            None                 1   159.000
# 1              JP                 1   207.000
# 2              SW                 1   100.000
# 3              UK                24   138.125
# 4             USA                 1    93.000

# %%
gender = pd.read_sql("SELECT * FROM gender", db_con)
gender
# Out:
#     genero  gen_title
# 0     1001     Action
# 1     1002  Adventure
# 2     1003  Animation
# 3     1004  Biography
# 4     1005     Comedy
# 5     1006      Crime
# 6     1007      Drama
# 7     1008     Horror
# 8     1009      Music
# 9     1010    Mystery
# 10    1011    Romance
# 11    1012   Thriller
# 12    1013        War

# %%
#Obtén los nombres de las películas de género Drama. SELECT, FROM, JOIN, WHERE

ex2_6 =  pd.read_sql("SELECT t1.mov_title AS name FROM movies as t1 JOIN gender as t2 ON t1.genero = t2.genero WHERE gen_title = 'Drama' ", db_con)
ex2_6
# Out:
#                   name
# 0   Back to the Future
# 1           Braveheart
# 2         Donnie Darko
# 3    Good Will Hunting
# 4        Seven Samurai
# 5  Slumdog Millionaire
# 6              Titanic
# 7        Trainspotting

# %% [markdown]
# # Accediendo y Manejando los Dataframes
# En esta sección veremos las formas más comunes de tratar con un dataframe. Como accedemos a las diferentes columnas y filas y cómo se utiliza el index.

# %%
#esta funcion nos indica cuantas filas y columnas tiene nuestro dataframe
movies = pd.read_sql("SELECT * FROM movies", db_con)
movies.shape
# Out:
# (28, 8)

# %%
#la funcion len() de python nos devuelve la longitud de objetos, arrays, y tambien de DataFrames
len(movies)
# Out:
# 28

# %%
# Podemos ver los valores de una sola columna escribiendo dataframe.nombrecolumna
movies.mov_title
# Out:
# 0                 Vertigo
# 1           The Innocents
# 2      Lawrence of Arabia
# 3         The Deer Hunter
# 4                 Amadeus
# 5            Blade Runner
# 6         Eyes Wides Shut
# 7      The Usual Suspects
# 8               Chinatown
# 9           Boogie Nights
# 10             Annie Hall
# 11      Princess Mononoke
# 12          The Shawshank
# 13        American Beauty
# 14                Titanic
# 15      Good Will Hunting
# 16            Deliverance
# 17          Trainspotting
# 18           The Prestige
# 19           Donnie Darko
# 20    Slumdog Millionaire
# 21                 Aliens
# 22         Beyond the Sea
# 23                 Avatar
# 24          Seven Samurai
# 25          Spirited Away
# 26     Back to the Future
# 27             Braveheart
# Name: mov_title, dtype: object

# %%
movies.mov_time
# Out:
# 0     128
# 1     100
# 2     216
# 3     183
# 4     160
# 5     117
# 6     159
# 7     106
# 8     130
# 9     155
# 10     93
# 11    134
# 12    142
# 13    122
# 14    194
# 15    126
# 16    109
# 17     94
# 18    130
# 19    113
# 20    120
# 21    137
# 22    118
# 23    162
# 24    207
# 25    125
# 26    116
# 27    178
# Name: mov_time, dtype: int64

# %%
#También podemos hacerlo de de esta forma
movies["mov_title"]
# Out:
# 0                 Vertigo
# 1           The Innocents
# 2      Lawrence of Arabia
# 3         The Deer Hunter
# 4                 Amadeus
# 5            Blade Runner
# 6         Eyes Wides Shut
# 7      The Usual Suspects
# 8               Chinatown
# 9           Boogie Nights
# 10             Annie Hall
# 11      Princess Mononoke
# 12          The Shawshank
# 13        American Beauty
# 14                Titanic
# 15      Good Will Hunting
# 16            Deliverance
# 17          Trainspotting
# 18           The Prestige
# 19           Donnie Darko
# 20    Slumdog Millionaire
# 21                 Aliens
# 22         Beyond the Sea
# 23                 Avatar
# 24          Seven Samurai
# 25          Spirited Away
# 26     Back to the Future
# 27             Braveheart
# Name: mov_title, dtype: object

# %%
#Para acceder a una fila segun su posición en el dataframe utilizaremos iloc
#help(movies.iloc)
movies.iloc[9]
# Out:
# mov_id                       910
# mov_title          Boogie Nights
# mov_year                    1997
# mov_time                     155
# mov_lang                 English
# mov_dt_rel            1998-02-16
# mov_rel_country               UK
# genero                      1005
# Name: 9, dtype: object

# %%
#Si lo que queremos es acceder a una columna por su posición, lo haremos indicando 
#que queremos todas las filas con : y la posicion de la columna deseada.
#Así seleccionamos la columna mov_title, que se encuentra en la segunda posición
movies.iloc[:, 1]
# Out:
# 0                 Vertigo
# 1           The Innocents
# 2      Lawrence of Arabia
# 3         The Deer Hunter
# 4                 Amadeus
# 5            Blade Runner
# 6         Eyes Wides Shut
# 7      The Usual Suspects
# 8               Chinatown
# 9           Boogie Nights
# 10             Annie Hall
# 11      Princess Mononoke
# 12          The Shawshank
# 13        American Beauty
# 14                Titanic
# 15      Good Will Hunting
# 16            Deliverance
# 17          Trainspotting
# 18           The Prestige
# 19           Donnie Darko
# 20    Slumdog Millionaire
# 21                 Aliens
# 22         Beyond the Sea
# 23                 Avatar
# 24          Seven Samurai
# 25          Spirited Away
# 26     Back to the Future
# 27             Braveheart
# Name: mov_title, dtype: object

# %%
#Recordad que podemos jugar con : de manera muy cómoda, tanto para seleccionar más de una fila coomo mas de una columna
movies.iloc[-5:]

#Ejecutad estas sentencias para comprobar  los resultados.
#movies.iloc[10:15, 1]
#movies.iloc[10:, 1:5]
#movies.iloc[:, 1:]
#movies.iloc[-5:]
# Out:
#     mov_id           mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 23     924              Avatar      2009  ...  2009-12-17              UK   1002
# 24     926       Seven Samurai      1954  ...  1954-04-26              JP   1007
# 25     927       Spirited Away      2001  ...  2003-09-12              UK   1010
# 26     928  Back to the Future      1985  ...  1985-12-04              UK   1007
# 27     925          Braveheart      1995  ...  1995-09-08              UK   1007
#
# [5 rows x 8 columns]

# %%
#Con iloc accedemos a los elementos basandonos en su posición, pero con loc lo hacemos basándonos en su Nombre/Etiqueta/Index
movies.loc[21]  #con esta sentencia conseguimos la fila 21
# Out:
# mov_id                    922
# mov_title              Aliens
# mov_year                 1986
# mov_time                  137
# mov_lang              English
# mov_dt_rel         1986-08-29
# mov_rel_country            UK
# genero                   1001
# Name: 21, dtype: object

# %%
#Podemos conseguir también la columna Country por su nombre.
#help(movies.loc)
movies.loc[:, "mov_title"]
# Out:
# 0                 Vertigo
# 1           The Innocents
# 2      Lawrence of Arabia
# 3         The Deer Hunter
# 4                 Amadeus
# 5            Blade Runner
# 6         Eyes Wides Shut
# 7      The Usual Suspects
# 8               Chinatown
# 9           Boogie Nights
# 10             Annie Hall
# 11      Princess Mononoke
# 12          The Shawshank
# 13        American Beauty
# 14                Titanic
# 15      Good Will Hunting
# 16            Deliverance
# 17          Trainspotting
# 18           The Prestige
# 19           Donnie Darko
# 20    Slumdog Millionaire
# 21                 Aliens
# 22         Beyond the Sea
# 23                 Avatar
# 24          Seven Samurai
# 25          Spirited Away
# 26     Back to the Future
# 27             Braveheart
# Name: mov_title, dtype: object

# %%
movies.loc[:, ["mov_title", "mov_year"]] #podemos conseguir más de una columna a la vez
# Out:
#               mov_title  mov_year
# 0               Vertigo      1958
# 1         The Innocents      1961
# 2    Lawrence of Arabia      1962
# 3       The Deer Hunter      1978
# 4               Amadeus      1984
# 5          Blade Runner      1982
# 6       Eyes Wides Shut      1999
# 7    The Usual Suspects      1995
# 8             Chinatown      1974
# 9         Boogie Nights      1997
# 10           Annie Hall      1977
# 11    Princess Mononoke      1997
# 12        The Shawshank      1994
# 13      American Beauty      1999
# 14              Titanic      1997
# 15    Good Will Hunting      1997
# 16          Deliverance      1972
# 17        Trainspotting      1996
# 18         The Prestige      2006
# 19         Donnie Darko      2001
# 20  Slumdog Millionaire      2008
# 21               Aliens      1986
# 22       Beyond the Sea      2004
# 23               Avatar      2009
# 24        Seven Samurai      1954
# 25        Spirited Away      2001
# ...

# %% [markdown]
# # ¿Recordáis que al leer de un archivo podíamos indicar la columna que serviría Index (es la forma que llama pandas al label o etiqueta)?
#
# También podemos crearlo nosotros manualmente con la función set_index()

# %%
actors = pd.read_sql("SELECT * FROM actors", db_con)
actors
# Out:
#     act_id           act_fname   act_lname act_gender
# 0               101      James     Stewart          M
# 1               102    Deborah        Kerr          F
# 2               103      Peter      Otoole          M
# 3               104     Robert     De Niro          M
# 4               105   F.Murray     Abraham          M
# 5               106   Harrison        Ford          M
# 6               107     Nicole      Kidman          F
# 7               108    Stephen     Bladwin          M
# 8               109       Jack   Nicholson          M
# 9               110       Mark    Wahlberg          M
# 10              111      Woody       Allen          M
# 11              112     Claire       Danes          F
# 12              113        Tim     Robbins          M
# 13              114      Kevin      Spacey          M
# 14              115       Kate     Winslet          F
# 15              116      Robin    Williams          M
# ...

# %%
actors.columns
# Out:
# Index(['act_id         ', 'act_fname', 'act_lname', 'act_gender'], dtype='object')

# %%
#actors.columns = ['act_id', 'act_fname', 'act_lname', 'act_gender']

# %%
actors.set_index(['act_id         '], inplace=True)

actors.head()
# Out:
#                 act_fname act_lname act_gender
# act_id
# 101                 James   Stewart          M
# 102               Deborah      Kerr          F
# 103                 Peter    Otoole          M
# 104                Robert   De Niro          M
# 105              F.Murray   Abraham          M

# %%
#Y ahora con .loc podemos encontrar filas por el ID del actor
actors.loc[104]
# Out:
# act_fname      Robert
# act_lname     De Niro
# act_gender          M
# Name: 104, dtype: object

# %% [markdown]
# #Acceso condicional para filtrar
# Hasta ahora hemos aprendido los basics de acceder a diferentes filas y columnas de un dataset. En esta sección aprenderemos como filtrar filas basándonos en los valores que contienen.

# %%
#Vereis que esta sentencia nos devuelve True o False para cada fila si cumple o no la condición.
movies.mov_year == 1999
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# Name: mov_year, dtype: bool

# %%
#Si pasamos el anterior trozo de código a loc, nos devolverá las filas que cumplen la condición.
movies.loc[movies.mov_year==1999]
# Out:
#     mov_id        mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 6      907  Eyes Wides Shut      1999  ...          UK            None   1010
# 13     914  American Beauty      1999  ...        None              UK   1011
#
# [2 rows x 8 columns]

# %%
#Podemos combinar y crear condiciones tan complicadas como necesitemos con & (Y) y | (O)
movies.loc[ (movies.mov_year==1958) & (movies.mov_lang=="English")]
# Out:
#    mov_id mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 0     901   Vertigo      1958  ...  1958-08-24              UK   1010
#
# [1 rows x 8 columns]

# %% [markdown]
# Existen varias funciones que nos facilitan la vida a la hora de seleccionar filas.
#
#
#
# *   isin nos permite especificar más de un valor válido
# *   notnull nos permite seleccionar las filas que no tengan valores nulos

# %%
#para seleccionar todas las filas cuyo valor de mov_rel_country cumpla uno de estos dos valores
movies.loc[movies.mov_rel_country.isin(["JP", "USA"])]
# Out:
#     mov_id      mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 10     911     Annie Hall      1977  ...  1977-04-20             USA   1005
# 24     926  Seven Samurai      1954  ...  1954-04-26              JP   1007
#
# [2 rows x 8 columns]

# %%
movies.loc[movies.mov_rel_country.isin(["JP", "USA"])==False] #podemos hacer la inversa añadiendo == False
# Out:
#     mov_id            mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 0      901              Vertigo      1958  ...  1958-08-24              UK   1010
# 1      902        The Innocents      1961  ...  1962-02-19              SW   1008
# 2      903   Lawrence of Arabia      1962  ...  1962-12-11              UK   1002
# 3      904      The Deer Hunter      1978  ...  1979-03-08              UK   1013
# 4      905              Amadeus      1984  ...  1985-01-07              UK   1004
# 5      906         Blade Runner      1982  ...  1982-09-09              UK   1012
# 6      907      Eyes Wides Shut      1999  ...          UK            None   1010
# 7      908   The Usual Suspects      1995  ...  1995-08-25              UK   1006
# 8      909            Chinatown      1974  ...  1974-08-09              UK   1001
# 9      910        Boogie Nights      1997  ...  1998-02-16              UK   1005
# ...

# %%
#todas las filas cuya region no sea null
movies.loc[movies.mov_rel_country.notnull()] #No sale la 6
# Out:
#     mov_id            mov_title  mov_year  ...  mov_dt_rel mov_rel_country genero
# 0      901              Vertigo      1958  ...  1958-08-24              UK   1010
# 1      902        The Innocents      1961  ...  1962-02-19              SW   1008
# 2      903   Lawrence of Arabia      1962  ...  1962-12-11              UK   1002
# 3      904      The Deer Hunter      1978  ...  1979-03-08              UK   1013
# 4      905              Amadeus      1984  ...  1985-01-07              UK   1004
# 5      906         Blade Runner      1982  ...  1982-09-09              UK   1012
# 7      908   The Usual Suspects      1995  ...  1995-08-25              UK   1006
# 8      909            Chinatown      1974  ...  1974-08-09              UK   1001
# 9      910        Boogie Nights      1997  ...  1998-02-16              UK   1005
# 10     911           Annie Hall      1977  ...  1977-04-20             USA   1005
# ...

# %% [markdown]
# # Asignando valores y creando nuevas columnas
# Hasta ahora hemos aprendido como juguetear con los datos que hemos leído. En esta seccion aprenderemos como creamos nuevas columnas para ir aumentando y enriqueciendo nuestro DataFrame.

# %% [markdown]
# Podemos asignar un valor igual a todas las filas del DataFrame de una manera muy sencilla. En ocasiones queremos añadir una columna nueva que contenga un valor.

# %%
movies["Formato"] = "Largometraje"
movies
# Out:
#     mov_id            mov_title  mov_year  ...  mov_rel_country genero       Formato
# 0      901              Vertigo      1958  ...               UK   1010  Largometraje
# 1      902        The Innocents      1961  ...               SW   1008  Largometraje
# 2      903   Lawrence of Arabia      1962  ...               UK   1002  Largometraje
# 3      904      The Deer Hunter      1978  ...               UK   1013  Largometraje
# 4      905              Amadeus      1984  ...               UK   1004  Largometraje
# 5      906         Blade Runner      1982  ...               UK   1012  Largometraje
# 6      907      Eyes Wides Shut      1999  ...             None   1010  Largometraje
# 7      908   The Usual Suspects      1995  ...               UK   1006  Largometraje
# 8      909            Chinatown      1974  ...               UK   1001  Largometraje
# 9      910        Boogie Nights      1997  ...               UK   1005  Largometraje
# ...

# %% [markdown]
# En otras ocasiones queremos que ese valor solo se aplique cuando se cumpla una condicion. En ese caso combinaremos lo aprendido en la sección anterior.

# %%
movies.loc[movies.mov_time > 200, "Formato"] = "Muy largometraje"
movies
# Out:
#     mov_id            mov_title  ...  genero           Formato
# 0      901              Vertigo  ...    1010      Largometraje
# 1      902        The Innocents  ...    1008      Largometraje
# 2      903   Lawrence of Arabia  ...    1002  Muy largometraje
# 3      904      The Deer Hunter  ...    1013      Largometraje
# 4      905              Amadeus  ...    1004      Largometraje
# 5      906         Blade Runner  ...    1012      Largometraje
# 6      907      Eyes Wides Shut  ...    1010      Largometraje
# 7      908   The Usual Suspects  ...    1006      Largometraje
# 8      909            Chinatown  ...    1001      Largometraje
# 9      910        Boogie Nights  ...    1005      Largometraje
# 10     911           Annie Hall  ...    1005      Largometraje
# 11     912    Princess Mononoke  ...    1003      Largometraje
# 12     913        The Shawshank  ...    1006      Largometraje
# 13     914      American Beauty  ...    1011      Largometraje
# ...

# %% [markdown]
# Podemos cambiar todos los valores que cumplen una condición o varias combinando los operadores.
#
# ---

# %%
movies.loc[(movies.mov_year > 1989) & (movies.mov_year < 2000), "mov_year"] = "90's"
movies
# Out:
#     mov_id            mov_title mov_year  ...  mov_dt_rel mov_rel_country genero
# 0      901              Vertigo     1958  ...  1958-08-24              UK   1010
# 1      902        The Innocents     1961  ...  1962-02-19              SW   1008
# 2      903   Lawrence of Arabia     1962  ...  1962-12-11              UK   1002
# 3      904      The Deer Hunter     1978  ...  1979-03-08              UK   1013
# 4      905              Amadeus     1984  ...  1985-01-07              UK   1004
# 5      906         Blade Runner     1982  ...  1982-09-09              UK   1012
# 6      907      Eyes Wides Shut     90's  ...          UK            None   1010
# 7      908   The Usual Suspects     90's  ...  1995-08-25              UK   1006
# 8      909            Chinatown     1974  ...  1974-08-09              UK   1001
# 9      910        Boogie Nights     90's  ...  1998-02-16              UK   1005
# 10     911           Annie Hall     1977  ...  1977-04-20             USA   1005
# ...

# %% [markdown]
# Podemos crear columnas como fórmulas matemáticas de otras columnas.

# %%
movies["mov_time_in_secs"] = movies["mov_time"] * 60
movies.head()
# Out:
#    mov_id           mov_title  ... genero  mov_time_in_secs
# 0     901             Vertigo  ...   1010              7680
# 1     902       The Innocents  ...   1008              6000
# 2     903  Lawrence of Arabia  ...   1002             12960
# 3     904     The Deer Hunter  ...   1013             10980
# 4     905             Amadeus  ...   1004              9600
#
# [5 rows x 9 columns]

# %% [markdown]
# # Exportando dataframes to_ function
#
# Haciendo operaciones sobre las columnas, aplicando funciones y filtrando lo que nos interesa, vamos a crear nuevos dataframes.
#
# Estos dataframes pueden exportarse a ficheros para ser usados más adelante.

# %%
#A csv
# Si trabajáis en local filpath --> movies.to_csv(path_or_buf= 'C:/Users/Toni/Desktop/THE_VALLEY/movies.csv', index = False)

#En colab

from google.colab import files

movies.to_csv('movies.csv', index = False)
files.download('movies.csv')

# %%
#A excel
# Si trabajáis en local filpath --> movies.to_excel('C:/Users/Toni/Desktop/THE_VALLEY/movies.xlsx', index = False)

#En colab

from google.colab import files

movies.to_excel('movies.xlsx', index = False)
files.download('movies.xlsx')

# %% [markdown]
# # EJERCICIO 3
#
# Utiliza lo aprendido en esta sesión para completar las siguientes acciones en un dataset de precios de casas en Ames, Iowa (USA).
#
# Fuente: http://jse.amstat.org/v19n3/decock.pdf
#
# Dataset info: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# url fichero: "https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/house_prices.csv"
#
# También puedes descargarlo de Kaggle y leerlo como un fichero local.
#
# 1. Lee el csv con pandas
# 2. Obtén el número de filas y columnas del dataframe
# 3. Obtén los nombres de las columnas del dataframe
# 4. Obtén un dataframe con los datos de las casas construidas después de 1999 con más de 3 habitaciones (columna BedroomAbvGr) y con el techo a dos aguas (RoofStyle == "Gable") y expórtalo como csv.
# 5. Lee el csv resultante y cambia los valores de la columna de 'CentralAir' de 'Y' y 'N' a 'Yes' y 'No'.
# 6. Del dataframe resultante Selecciona solo aquellas filas que tengan info sobre la calidad de la chimenea, es decir, cuya valor en la columna FireplaceQu no sea nulo.
# 7. Trabajas en la inmobiliaria que está vendiendo las casas del dataset. La inmobiliaria ha decidido aplicar un descuento del 10% a aquellas casas con más de 15 años y un 5% de descuento a aquellas casas que tienen entre 12 y 15 años (desde el año de la última remodelación: YearRemodAdd). Crea una columna llamada Discount que registre estos descuentos y otra columna con el precio final de la casa aplicando el descuento sobre la columna SalePrice.

# %%
houseprices = pd.read_csv("https://raw.githubusercontent.com/tonilopezrosell/datasciencemasterthevalley/main/house_prices.csv")
houseprices
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
houseprices.shape
# Out:
# (1460, 81)

# %%
houseprices.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#Obtén un dataframe con los datos de las casas construidas después de 1999 con más de 3 habitaciones (columna BedroomAbvGr) y con el techo a dos aguas (RoofStyle == "Gable") y expórtalo como csv.

ex3 = houseprices.loc[(houseprices.YearBuilt > 1999) & (houseprices.BedroomAbvGr > 3) & (houseprices.RoofStyle == 'Gable')]

from google.colab import files

ex3.to_csv('ex3.csv', index = False)
files.download('ex3.csv')

# %%
#Lee el csv resultante y cambia los valores de la columna de 'CentralAir' de 'Y' y 'N' a 'Yes' y 'No'.

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f56209e-616e-439b-b5b7-f368fabc5004" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f56209e-616e-439b-b5b7-f368fabc5004">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ex3.csv to ex3 (1).csv

# %%
import io
ex3 = pd.read_csv(io.BytesIO(uploaded['ex3.csv']))
ex3

# %%
ex3.loc[ex3.CentralAir == 'Y', 'CentralAir'] = 'Yes'
ex3.loc[ex3.CentralAir == 'N', 'CentralAir'] = 'No'
ex3.head()
# Out:
#     Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0    5          60       RL  ...        WD         Normal    250000
# 1   21          60       RL  ...       New        Partial    325300
# 2   36          60       RL  ...        WD         Normal    309000
# 3   66          60       RL  ...        WD         Normal    317000
# 4  113          60       RL  ...       New        Partial    383970
#
# [5 rows x 81 columns]

# %%
#Del dataframe resultante Selecciona solo aquellas filas que tengan info sobre la calidad de la chimenea, es decir, cuya valor en la columna FireplaceQu no sea nulo

ex3.loc[ex3.FireplaceQu.notnull()]
# Out:
#       Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0      5          60       RL  ...        WD         Normal    250000
# 1     21          60       RL  ...       New        Partial    325300
# 2     36          60       RL  ...        WD         Normal    309000
# 3     66          60       RL  ...        WD         Normal    317000
# 4    113          60       RL  ...       New        Partial    383970
# 5    158          60       RL  ...       New        Partial    269500
# 6    160          60       RL  ...       New        Partial    320000
# 7    222          60       RL  ...     ConLI         Normal    200000
# 8    235          60       RL  ...        WD         Normal    216500
# 10   322          60       RL  ...        WD         Normal    354000
# 12   363          85       RL  ...     ConLD         Normal    198500
# 13   375          60       RL  ...        WD         Normal    219500
# ...

# %%
#Trabajas en la inmobiliaria que está vendiendo las casas del dataset. La inmobiliaria ha decidido aplicar un descuento del 10% a aquellas casas con más de 15 años
#y un 5% de descuento a aquellas casas que tienen entre 12 y 15 años (desde el año de la última remodelación: YearRemodAdd). 
#Crea una columna llamada Discount_perc que registre estos descuentos y otra columna con el precio final de la casa aplicando el descuento sobre la columna SalePrice.

ex3.loc[ex3.YearRemodAdd < 2006, 'Discount_perc'] = 10
ex3.loc[(ex3.YearRemodAdd >= 2006) & (ex3.YearRemodAdd <= 2009), 'Discount_perc'] = 5
ex3.loc[ex3.YearRemodAdd > 2009, 'Discount_perc'] = 0
ex3['Final_Price'] = ex3['SalePrice'] - (ex3['SalePrice'] * (ex3['Discount_perc']/100))
ex3.head()
# Out:
#     Id  MSSubClass MSZoning  ...  SalePrice  Discount_perc Final_Price
# 0    5          60       RL  ...     250000           10.0    225000.0
# 1   21          60       RL  ...     325300            5.0    309035.0
# 2   36          60       RL  ...     309000           10.0    278100.0
# 3   66          60       RL  ...     317000           10.0    285300.0
# 4  113          60       RL  ...     383970            5.0    364771.5
#
# [5 rows x 83 columns]
